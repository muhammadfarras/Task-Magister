# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
# Load data iris
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# Data Frame diatas belum ada dependent variabel, sekarang kita masukan target value

# %%
df['tipe_bunga'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    tipe_bunga
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ## Tipe-tipe bunga

# %%
df_sentosa = df[df['tipe_bunga'] == 0]
df_sentosa.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    tipe_bunga
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df_versi_color = df[df['tipe_bunga'] == 1]
df_versi_color.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     tipe_bunga
# 50           1
# 51           1
# 52           1
# 53           1
# 54           1

# %%
df_virginica = df[df['tipe_bunga'] == 2]
df_virginica.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      tipe_bunga
# 100           2
# 101           2
# 102           2
# 103           2
# 104           2

# %%
df['nama_bunga'] = df.tipe_bunga.apply(lambda x : iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      tipe_bunga nama_bunga
# 0             0     setosa
# 1             0     setosa
# 2             0     setosa
# 3             0     setosa
# 4             0     setosa
# ..          ...        ...
# 145           2  virginica
# 146           2  virginica
# 147           2  virginica
# 148           2  virginica
# 149           2  virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Plot data bunga

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df_sentosa['sepal length (cm)'], df_sentosa['sepal width (cm)'], color='green', marker='+')
plt.scatter(df_versi_color['sepal length (cm)'], df_versi_color['sepal width (cm)'], color='blue', marker='*')
plt.scatter(df_virginica['sepal length (cm)'], df_virginica['sepal width (cm)'], color='red', marker='.')
