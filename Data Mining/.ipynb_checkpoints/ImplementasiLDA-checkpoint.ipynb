# %% [markdown]
# # LDA
# _Latent Dirichlet Allocation_

# %% [markdown]
# ## Sumber
# Farras baca lebih lanjut disini untuk lebih mengerti [Sumbernya Gaaaaan!](https://www.kaggle.com/code/rowhitswami/keywords-extraction-using-tf-idf-method)

# %% [markdown]
# ### Lets write something that my wife couldn't understand

# %%
# Import time
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# ### Load the data
# Saya menggunakan data dari google API, udah di download, tinggal panggil datanya

# %%
# df = pd.DataFrame.from_dict(comments)

df = pd.read_csv('Data/dummy_email_data.csv')
# df['real_index'] = df.index
# df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    nomor urut                                    deskripsi email  \
# 0           1  Saya sangat puas dengan fitur ini karena memba...
# 1           2  Saya sangat kecewa dengan fitur ini karena ser...
# 2           3  Selamat! klik di sini untuk memenangkan hadiah...
# 3           4  Saya sangat puas dengan fitur ini karena membe...
# 4           5  Saya sangat kecewa dengan fitur ini karena mem...
#
#                   pengirim
# 0     feedback@company.com
# 1  disappointed@domain.com
# 2  offer@cheapproducts.com
# 3     supporter@client.org
# 4     complaint@client.org

# %% [markdown]
# ### Fungsi pembantu

# %%
def clean_text(text):
    """Doc cleaning"""
    
    # Lowering text
    text = text.lower()
    
    # Removing punctuation
    text = "".join([c for c in text if c not in PUNCTUATION])
    
    # Removing whitespace and newlines
    text = re.sub('\\s+',' ',text)
    
    return text

def sort_coo(coo_matrix):
    """Sort a dict with highest score"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature, score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

def get_keywords(vectorizer, feature_names, doc):
    #generate tf-idf
    tf_idf_vector = vectorizer.transform([doc])
    
    #mengurutkan tf-idf vectors dengan descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #Hanya mengambil 10 kalimat paling sering muncul
    keywords=extract_topn_from_vector(feature_names,sorted_items,10)
    
    return list(keywords.keys())

# %%
# Static variable
PUNCTUATION = """!"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~"""

# %%
stopwords_list = stopwords.words('indonesian')

# %%
### Calculate

# %%
deskripsi = df['deskripsi email'].to_list()

vectorizer = TfidfVectorizer(stop_words=stopwords_list, smooth_idf=True, use_idf=True)# Creating vocab with our corpora
# Exlcluding first 10 docs for testing purpose
vectorizer.fit_transform(deskripsi)

# Storing vocab
feature_names = vectorizer.get_feature_names_out()
# Out:
# D:\conda\Lib\site-packages\sklearn\feature_extraction\text.py:406: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['baiknya', 'berkali', 'kali', 'kurangnya', 'mata', 'olah', 'sekurang', 'setidak', 'tama', 'tidaknya'] not in stop_words.
#   warnings.warn(

# %%
result = []
for doc in deskripsi:
    df = {}
    df['full_text'] = doc
    df['top_keywords'] = get_keywords(vectorizer, feature_names, doc)
    result.append(df)
    
final = pd.DataFrame(result)
final.index +=1
final
# Out:
#                                             full_text  \
# 1   Saya sangat puas dengan fitur ini karena memba...
# 2   Saya sangat kecewa dengan fitur ini karena ser...
# 3   Selamat! klik di sini untuk memenangkan hadiah...
# 4   Saya sangat puas dengan fitur ini karena membe...
# 5   Saya sangat kecewa dengan fitur ini karena mem...
# 6   Selamat! dapatkan jutaan rupiah hanya dari rum...
# 7   Saya sangat puas dengan fitur ini karena membu...
# 8   Saya sangat kecewa dengan fitur ini karena tid...
# 9   Selamat! program ini telah membuat ribuan oran...
# 10  Saya sangat puas dengan fitur ini karena menye...
# 11  Saya sangat kecewa dengan fitur ini karena men...
# 12  Selamat! jangan lewatkan kesempatan langka ini...
# 13  Saya sangat puas dengan fitur ini karena mengh...
# 14  Saya sangat kecewa dengan fitur ini karena ant...
# 15  Selamat! kami jamin uang kembali jika Anda tid...
# 16  Saya sangat puas dengan fitur ini karena memud...
# 17  Saya sangat kecewa dengan fitur ini karena tid...
# 18  Selamat! hanya hari ini! penawaran eksklusif u...
# 19  Saya sangat puas dengan fitur ini karena fitur...
# 20  Saya sangat kecewa dengan fitur ini karena ban...
# 21  Selamat! bergabung sekarang dan dapatkan bonus...
# 22  Saya sangat puas dengan fitur ini karena menin...
# 23  Saya sangat kecewa dengan fitur ini karena men...
# 24  Selamat! kerja santai tanpa bos dan dapatkan p...
# 25  Saya sangat puas dengan fitur ini karena sanga...
# 26  Saya sangat kecewa dengan fitur ini karena men...
# 27  Selamat! ikuti program afiliasi kami dan hasil...
# 28  Saya sangat puas dengan fitur ini karena fitur...
# 29  Saya sangat kecewa dengan fitur ini karena pel...
# 30  Selamat! tidak perlu pengalaman, semua orang b...
#
#                                          top_keywords
# 1   [tugas, pengelolaan, harian, membantu, solusi,...
# 2   [menyebabkan, crash, solusi, pengguna, aplikas...
# 3   [klik, memenangkan, iphone, hadiah, terbaru, t...
# 4   [proyek, pelacakan, kemudahan, solusi, penggun...
# 5   [pekerjaan, efisien, solusi, pengguna, lambat,...
# 6   [rumah, modal, jutaan, rupiah, dapatkan, terba...
# 7   [kolaborasi, efisien, tim, solusi, pengguna, m...
# 8   [pengguna, kebutuhan, solusi, profesional, ses...
# 9   [ribuan, orang, miliarder, program, terbatas, ...
# 10  [mudah, menyediakan, laporan, komprehensif, di...
# 11  [mengganggu, bug, alur, solusi, pengguna, hara...
# 12  [lewatkan, kesempatan, langka, kaya, terbatas,...
# 13  [menyusun, menghemat, jadwal, solusi, pengguna...
# 14  [pengguna, membingungkan, antarmuka, ramah, me...
# 15  [jamin, uang, terbatas, sukses, selamat, rumah...
# 16  [pengambilan, memudahkan, keputusan, data, aku...
# 17  [update, peningkatan, terbaru, solusi, penggun...
# 18  [penawaran, eksklusif, terbatas, sukses, selam...
# 19  [pengguna, fitur, intuitif, barunya, ramah, so...
# 20  [fungsi, dijanjikan, solusi, pengguna, harapan...
# 21  [juta, bonus, bergabung, rupiah, dapatkan, ter...
# 22  [signifikan, produktivitas, meningkatkan, tim,...
# 23  [sistem, mengalami, integrasi, solusi, serius,...
# 24  [santai, penghasilan, bos, kerja, dapatkan, te...
# 25  [pengguna, merespons, cepat, kebutuhan, solusi...
# 26  [salah, output, menghasilkan, konsisten, menge...
# 27  [otomatis, ikuti, hasilkan, afiliasi, uang, pr...
# 28  [time, real, notifikasinya, diandalkan, solusi...
# 29  [pelayanan, bantuan, membantu, mengecewakan, s...
# 30  [orang, berhasil, terbatas, sukses, selamat, r...

# %%
## Bags of words kalimat spam

# %%
topKeywordsSpam = final[final.index % 3 == 0].top_keywords
# Append datra
list_spam_top_list_words = [' '.join(a) for a in topKeywordsSpam]
string_spam_topList_words =' '.join(list_spam_top_list_words)
string_spam_topList_words
# Out:
# 'klik memenangkan iphone hadiah terbaru terbatas sukses selamat rumah ribuan rumah modal jutaan rupiah dapatkan terbatas sukses selamat ribuan penawaran ribuan orang miliarder program terbatas sukses selamat rumah penawaran lewatkan lewatkan kesempatan langka kaya terbatas sukses selamat rumah ribuan penawaran jamin uang terbatas sukses selamat rumah ribuan penawaran orang lewatkan penawaran eksklusif terbatas sukses selamat rumah ribuan orang lewatkan klik juta bonus bergabung rupiah dapatkan terbatas sukses selamat rumah ribuan santai penghasilan bos kerja dapatkan terbatas sukses selamat rumah ribuan otomatis ikuti hasilkan afiliasi uang program terbatas sukses selamat rumah orang berhasil terbatas sukses selamat rumah ribuan penawaran lewatkan klik'

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(string_spam_topList_words)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
lda_model=LatentDirichletAllocation(n_components=30,learning_method='online',random_state=42,max_iter=1)

# %%
vect_text=vectorizer.fit_transform(final['full_text'])

vect_text
# Out:
# <30x135 sparse matrix of type '<class 'numpy.float64'>'
# 	with 952 stored elements in Compressed Sparse Row format>

# %%
lda_top=lda_model.fit_transform(vect_text)
print(lda_top.shape)  # (no_of_doc,no_of_topics)
print(lda_top)
# Out:
# (30, 30)
# [[0.00500496 0.00500496 0.00500496 0.85485602 0.00500496 0.00500496
#   0.00500496 0.00500496 0.00500496 0.00500496 0.00500496 0.00500496
#   0.00500496 0.00500496 0.00500496 0.00500496 0.00500496 0.00500496
#   0.00500496 0.00500496 0.00500496 0.00500496 0.00500496 0.00500496
#   0.00500496 0.00500496 0.00500496 0.00500496 0.00500496 0.00500496]
#  [0.00499713 0.00499713 0.00499713 0.00499713 0.00499713 0.00499713
#   0.00499713 0.00499713 0.85508312 0.00499713 0.00499713 0.00499713
#   0.00499713 0.00499713 0.00499713 0.00499713 0.00499713 0.00499713
#   0.00499713 0.00499713 0.00499713 0.00499713 0.00499713 0.00499713
#   0.00499713 0.00499713 0.00499713 0.00499713 0.00499713 0.00499713]
#  [0.00623207 0.00623207 0.00623207 0.00623207 0.00623207 0.00623207
#   0.00623207 0.00623207 0.00623207 0.00623207 0.00623207 0.00623207
#   0.00623207 0.00623207 0.00623207 0.00623207 0.00623207 0.00623207
#   0.00623207 0.00623207 0.00623207 0.00623207 0.00623207 0.00623207
#   0.00503182 0.00503182 0.00503182 0.00503182 0.00503182 0.00503182]
#  [0.00598152 0.00598152 0.00598152 0.00598152 0.00598152 0.00598152
#   0.00598152 0.00598152 0.00598152 0.00598152 0.00598152 0.00598152
#   0.00598152 0.00598152 0.00598152 0.00598152 0.00598152 0.00598152
#   0.00598152 0.00598152 0.82653604 0.00598152 0.00598152 0.00598152
#   0.00598152 0.00598152 0.00598152 0.00598152 0.00598152 0.00598152]
#  [0.85620438 0.00495847 0.00495847 0.00495847 0.00495847 0.00495847
#   0.00495847 0.00495847 0.00495847 0.00495847 0.00495847 0.00495847
#   0.00495847 0.00495847 0.00495847 0.00495847 0.00495847 0.00495847
#   0.00495847 0.00495847 0.00495847 0.00495847 0.00495847 0.00495847
#   0.00495847 0.00495847 0.00495847 0.00495847 0.00495847 0.00495847]
#  [0.85392874 0.00503694 0.00503694 0.00503694 0.00503694 0.00503694
#   0.00503694 0.00503694 0.00503694 0.00503694 0.00503694 0.00503694
#   0.00503694 0.00503694 0.00503694 0.00503694 0.00503694 0.00503694
#   0.00503694 0.00503694 0.00503694 0.00503694 0.00503694 0.00503694
#   0.00503694 0.00503694 0.00503694 0.00503694 0.00503694 0.00503694]
#  [0.00653688 0.00653688 0.00653688 0.00653688 0.00653688 0.00653688
#   0.00653688 0.00653688 0.00653688 0.00653688 0.00653688 0.00653688
#   0.00653688 0.00653688 0.00653688 0.00653688 0.00653688 0.00653688
#   0.00653688 0.00653688 0.00653688 0.00653688 0.00653688 0.00653688
#   0.00653688 0.00653688 0.00653688 0.00653688 0.00653688 0.81043046]]

# %%
# most important words for each topic
vocab = vectorizer.get_feature_names_out()

for i, comp in enumerate(lda_model.components_,1):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    if i % 3 == 0:
        print("Topic "+str(i)+": ")
        for t in sorted_words:
            print(t[0],end=" ")
        print("\n")
# Out:
# Topic 3:
# mencoba real proses miliarder kebutuhan serius afiliasi solusi efisien menyusun
#
# Topic 6:
# eksklusif membingungkan jutaan santai sesuai hasilnya rumah harian kesempatan serius
#
# Topic 9:
# sesuai crash produktivitas bos terima menyebabkan solusi pengembang ribuan akurat
#
# Topic 12:
# kesempatan keputusan santai produktivitas memudahkan real bantuan selamat menanggapi kali
#
# Topic 15:
# ditingkatkan proyek update juta menghabiskan bos berharap kesempatan hadiah sukses
#
# Topic 18:
# penawaran orang kesempatan pengguna menyusun akurat fungsional hasilnya dijanjikan selamat
#
# Topic 21:
# afiliasi signifikan kecewa santai uang terbatas program orang klik kesempatan
#
# Topic 24:
# pengguna dipahami kasih sukses eksklusif memahami mencoba kendala efisien alur
#
# Topic 27:
# menemui cepat kerja notifikasinya salah lambat mencoba kasih iphone kali
#
# Topic 30:
# bebas eksklusif miliarder hidup penawaran jamin kesempatan membantu crash barunya
